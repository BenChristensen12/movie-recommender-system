# %%
import numpy as np
from sklearn.decomposition import NMF
from sklearn.metrics import mean_absolute_error

import pandas as pd
from scipy import linalg as la
from scipy.sparse import csr_matrix
from pandas.api.types import CategoricalDtype
from scipy.sparse import linalg as spla

# %%
#Benjamin's path: path = "/Users/Armen/Desktop/SpringDataProject/"
#Ben C's path: path = "/Users/benchristensen/Desktop/Recommneder_System_Project/ml-20m/"
path = "/Users/Armen/Desktop/SpringDataProject/"
r = pd.read_csv(path+"ratings.csv",nrows=1000000)

# %%
m = pd.read_csv(path+'movies.csv',index_col = 0)

# %%
#get only those movies with more than 17 ratings (cutting out ~50% of movies)
merged = r.merge(r.groupby("movieId").size().reset_index(name='count'),
                 how='right', on='movieId')
df = merged[merged["count"]>17].sort_values(['userId', 'movieId'])

#create a matrix from the ratings list
user_c = CategoricalDtype(sorted(df.userId.unique()), ordered=True)
movie_c = CategoricalDtype(sorted(df.movieId.unique()), ordered=True)
row = df.userId.astype(user_c).cat.codes
col = df.movieId.astype(movie_c).cat.codes

#this matrix is movies x users
sparse_matrix = csr_matrix((df['rating'], (row, col)), \
                           shape=(user_c.categories.size, movie_c.categories.size)).T

#we can't deal with these NaN's, so we're lazy and just replace them all with 3's
dfs = pd.SparseDataFrame(sparse_matrix, \
                     index=movie_c.categories, \
                     columns=user_c.categories, \
                     default_fill_value=2.5)

# %%
model = NMF(n_components = 20,init='random')
W = model.fit_transform(dfs)
H = model.components_
X = W@H

# %%
def get_topics(W):
    """Each column of W contains a 'relevance score' for how much each movie 
        is related to the 20 "types" we found. This function gets the top
        # of movies in that group and returns them together as strings
    """
    top = 10
    data = []
    for i in range(W.shape[1]):
        scores = W[:,i]
        positions = np.argsort(scores)[-top:]
        
        movie_ids = np.array(movie_c.categories)[positions]
        strings = []
        for ind,j in enumerate(movie_ids):
            strings.append(m.loc[j].title + m.loc[j].genres)
        data.append(strings)
        
    return pd.DataFrame(np.array(data).T)

# %%
print(get_topics(W))
# Out:
#                                                   0   \
# 0                        Karate Kid, The (1984)Drama
# 1    King Kong (1933)Action|Adventure|Fantasy|Horror
# 2  Wallace & Gromit: The Best of Aardman Animatio...
# 3                    Kalifornia (1993)Drama|Thriller
# 4                          Analyze This (1999)Comedy
# 5                        Richard III (1995)Drama|War
# 6  Antz (1998)Adventure|Animation|Children|Comedy...
# 7    Sneakers (1992)Action|Comedy|Crime|Drama|Sci-Fi
# 8  Dracula (Bram Stoker's Dracula) (1992)Fantasy|...
# 9  Who Framed Roger Rabbit? (1988)Adventure|Anima...
#
#                                                   1   \
# 0  Spy Who Loved Me, The (1977)Action|Adventure|T...
# 1  Man with the Golden Gun, The (1974)Action|Adve...
# 2         Goldfinger (1964)Action|Adventure|Thriller
# 3                        Richard III (1995)Drama|War
# 4  Outlaw Josey Wales, The (1976)Action|Adventure...
# 5                  High Plains Drifter (1973)Western
# 6  Who Framed Roger Rabbit? (1988)Adventure|Anima...
# 7               Blazing Saddles (1974)Comedy|Western
# 8  Dracula (Bram Stoker's Dracula) (1992)Fantasy|...
# 9                          Animal House (1978)Comedy
#
#                                                   2   \
# 0  Interview with the Vampire: The Vampire Chroni...
# 1   Singin' in the Rain (1952)Comedy|Musical|Romance
# 2  Aladdin (1992)Adventure|Animation|Children|Com...
# 3  Nightmare Before Christmas, The (1993)Animatio...
# 4  Silence of the Lambs, The (1991)Crime|Horror|T...
# 5        Shawshank Redemption, The (1994)Crime|Drama
# 6     Pulp Fiction (1994)Comedy|Crime|Drama|Thriller
# 7  Who Framed Roger Rabbit? (1988)Adventure|Anima...
# 8   Usual Suspects, The (1995)Crime|Mystery|Thriller
# 9        Seven (a.k.a. Se7en) (1995)Mystery|Thriller
#
#                                                   3   \
# 0  City of God (Cidade de Deus) (2002)Action|Adve...
# 1                          Shining, The (1980)Horror
# 2  Eternal Sunshine of the Spotless Mind (2004)Dr...
# 3          Godfather: Part II, The (1974)Crime|Drama
# 4                   Schindler's List (1993)Drama|War
# 5              Apocalypse Now (1979)Action|Drama|War
# 6                   Godfather, The (1972)Crime|Drama
# 7        Shawshank Redemption, The (1994)Crime|Drama
# 8        One Flew Over the Cuckoo's Nest (1975)Drama
# 9        Forrest Gump (1994)Comedy|Drama|Romance|War
#
#                                                   4   \
# 0       Terminator, The (1984)Action|Sci-Fi|Thriller
# 1  Butch Cassidy and the Sundance Kid (1969)Actio...
# 2                             Airplane! (1980)Comedy
# 3       M*A*S*H (a.k.a. MASH) (1970)Comedy|Drama|War
# 4  Monty Python and the Holy Grail (1975)Adventur...
# 5   Back to the Future (1985)Adventure|Comedy|Sci-Fi
# 6            Young Frankenstein (1974)Comedy|Fantasy
# 7                           Jaws (1975)Action|Horror
# 8  Ghostbusters (a.k.a. Ghost Busters) (1984)Acti...
# 9    Blues Brothers, The (1980)Action|Comedy|Musical
#
#                                                   5   \
# 0  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)Myste...
# 1                     Memento (2000)Mystery|Thriller
# 2  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 3  Monty Python and the Holy Grail (1975)Adventur...
# 4          Blade Runner (1982)Action|Sci-Fi|Thriller
# 5           Matrix, The (1999)Action|Sci-Fi|Thriller
# 6     Pulp Fiction (1994)Comedy|Crime|Drama|Thriller
# 7  Lord of the Rings: The Two Towers, The (2002)A...
# 8  Lord of the Rings: The Return of the King, The...
# 9  Lord of the Rings: The Fellowship of the Ring,...
#
#                                                   6   \
# 0       English Patient, The (1996)Drama|Romance|War
# 1   Usual Suspects, The (1995)Crime|Mystery|Thriller
# 2                       Goodfellas (1990)Crime|Drama
# 3                  Jerry Maguire (1996)Drama|Romance
# 4              Leaving Las Vegas (1995)Drama|Romance
# 5          Godfather: Part II, The (1974)Crime|Drama
# 6  L.A. Confidential (1997)Crime|Film-Noir|Myster...
# 7                 Dead Man Walking (1995)Crime|Drama
# 8                   Godfather, The (1972)Crime|Drama
# 9            Fargo (1996)Comedy|Crime|Drama|Thriller
#
#                                                   7   \
# 0  Toy Story (1995)Adventure|Animation|Children|C...
# 1  Aladdin (1992)Adventure|Animation|Children|Com...
# 2   Dances with Wolves (1990)Adventure|Drama|Western
# 3                  Pretty Woman (1990)Comedy|Romance
# 4  Jurassic Park (1993)Action|Adventure|Sci-Fi|Th...
# 5                  Braveheart (1995)Action|Drama|War
# 6                       Fugitive, The (1993)Thriller
# 7  Lion King, The (1994)Adventure|Animation|Child...
# 8               Apollo 13 (1995)Adventure|Drama|IMAX
# 9        Forrest Gump (1994)Comedy|Drama|Romance|War
#
#                                                   8   \
# 0       Terminator, The (1984)Action|Sci-Fi|Thriller
# 1  Dr. Strangelove or: How I Learned to Stop Worr...
# 2  Clockwork Orange, A (1971)Crime|Drama|Sci-Fi|T...
# 3          Blade Runner (1982)Action|Sci-Fi|Thriller
# 4        Aliens (1986)Action|Adventure|Horror|Sci-Fi
# 5  2001: A Space Odyssey (1968)Adventure|Drama|Sc...
# 6  Star Wars: Episode V - The Empire Strikes Back...
# 7                          Alien (1979)Horror|Sci-Fi
# 8  Star Wars: Episode VI - Return of the Jedi (19...
# 9  Star Wars: Episode IV - A New Hope (1977)Actio...
#
#                                                   9   \
# 0  Star Wars: Episode VI - Return of the Jedi (19...
# 1                       Goodfellas (1990)Crime|Drama
# 2  Silence of the Lambs, The (1991)Crime|Horror|T...
# 3                   Godfather, The (1972)Crime|Drama
# 4  Star Wars: Episode IV - A New Hope (1977)Actio...
# 5  Raiders of the Lost Ark (Indiana Jones and the...
# 6  Star Wars: Episode V - The Empire Strikes Back...
# 7        Shawshank Redemption, The (1994)Crime|Drama
# 8   Usual Suspects, The (1995)Crime|Mystery|Thriller
# 9     Pulp Fiction (1994)Comedy|Crime|Drama|Thriller
#
#                                                   10  \
# 0  Toy Story (1995)Adventure|Animation|Children|C...
# 1        Ace Ventura: When Nature Calls (1995)Comedy
# 2  Shrek (2001)Adventure|Animation|Children|Comed...
# 3  Austin Powers: International Man of Mystery (1...
# 4              Ferris Bueller's Day Off (1986)Comedy
# 5  Monsters, Inc. (2001)Adventure|Animation|Child...
# 6  Dumb & Dumber (Dumb and Dumber) (1994)Adventur...
# 7  Finding Nemo (2003)Adventure|Animation|Childre...
# 8            Ace Ventura: Pet Detective (1994)Comedy
# 9                    Office Space (1999)Comedy|Crime
#
#                                                   11  \
# 0                Some Like It Hot (1959)Comedy|Crime
# 1        Maltese Falcon, The (1941)Film-Noir|Mystery
# 2  Wizard of Oz, The (1939)Adventure|Children|Fan...
# 3                    Annie Hall (1977)Comedy|Romance
# 4                          Psycho (1960)Crime|Horror
# 5  North by Northwest (1959)Action|Adventure|Myst...
# 6       Vertigo (1958)Drama|Mystery|Romance|Thriller
# 7                   Citizen Kane (1941)Drama|Mystery
# 8                     Casablanca (1942)Drama|Romance
# 9                 Rear Window (1954)Mystery|Thriller
#
#                                                   12  \
# 0  Independence Day (a.k.a. ID4) (1996)Action|Adv...
# 1  Star Wars: Episode I - The Phantom Menace (199...
# 2         Saving Private Ryan (1998)Action|Drama|War
# 3                  Braveheart (1995)Action|Drama|War
# 4        Sixth Sense, The (1999)Drama|Horror|Mystery
# 5  Lord of the Rings: The Return of the King, The...
# 6           Matrix, The (1999)Action|Sci-Fi|Thriller
# 7             Gladiator (2000)Action|Adventure|Drama
# 8  Lord of the Rings: The Two Towers, The (2002)A...
# 9  Lord of the Rings: The Fellowship of the Ring,...
#
#                                                   13  \
# 0                     Piano, The (1993)Drama|Romance
# 1        Remains of the Day, The (1993)Drama|Romance
# 2                  Braveheart (1995)Action|Drama|War
# 3   Usual Suspects, The (1995)Crime|Mystery|Thriller
# 4   Dances with Wolves (1990)Adventure|Drama|Western
# 5        Seven (a.k.a. Se7en) (1995)Mystery|Thriller
# 6                   Schindler's List (1993)Drama|War
# 7  Silence of the Lambs, The (1991)Crime|Horror|T...
# 8     Pulp Fiction (1994)Comedy|Crime|Drama|Thriller
# 9        Shawshank Redemption, The (1994)Crime|Drama
#
#                                                   14  \
# 0  Monty Python and the Holy Grail (1975)Adventur...
# 1  Independence Day (a.k.a. ID4) (1996)Action|Adv...
# 2  Star Wars: Episode V - The Empire Strikes Back...
# 3    Twister (1996)Action|Adventure|Romance|Thriller
# 4                         Happy Gilmore (1996)Comedy
# 5  Star Wars: Episode VI - Return of the Jedi (19...
# 6  Princess Bride, The (1987)Action|Adventure|Com...
# 7  Toy Story (1995)Adventure|Animation|Children|C...
# 8  Star Wars: Episode IV - A New Hope (1977)Actio...
# 9  Willy Wonka & the Chocolate Factory (1971)Chil...
#
#                                                   15  \
# 0   V for Vendetta (2006)Action|Sci-Fi|Thriller|IMAX
# 1  Inception (2010)Action|Crime|Drama|Mystery|Sci...
# 2  Lord of the Rings: The Return of the King, The...
# 3  Pirates of the Caribbean: The Curse of the Bla...
# 4      Casino Royale (2006)Action|Adventure|Thriller
# 5  Bourne Identity, The (2002)Action|Mystery|Thri...
# 6  Bourne Ultimatum, The (2007)Action|Crime|Thriller
# 7             Iron Man (2008)Action|Adventure|Sci-Fi
# 8              Batman Begins (2005)Action|Crime|IMAX
# 9     Dark Knight, The (2008)Action|Crime|Drama|IMAX
#
#                                                   16  \
# 0        Outbreak (1995)Action|Drama|Sci-Fi|Thriller
# 1             Stargate (1994)Action|Adventure|Sci-Fi
# 2  Clear and Present Danger (1994)Action|Crime|Dr...
# 3            Ace Ventura: Pet Detective (1994)Comedy
# 4  Jurassic Park (1993)Action|Adventure|Sci-Fi|Th...
# 5                       Fugitive, The (1993)Thriller
# 6                Speed (1994)Action|Romance|Thriller
# 7  True Lies (1994)Action|Adventure|Comedy|Romanc...
# 8  Die Hard: With a Vengeance (1995)Action|Crime|...
# 9     Terminator 2: Judgment Day (1991)Action|Sci-Fi
#
#                                                   17  \
# 0         Truman Show, The (1998)Comedy|Drama|Sci-Fi
# 1       Run Lola Run (Lola rennt) (1998)Action|Crime
# 2    Edward Scissorhands (1990)Drama|Fantasy|Romance
# 3               American History X (1998)Crime|Drama
# 4       Fight Club (1999)Action|Crime|Drama|Thriller
# 5        Sixth Sense, The (1999)Drama|Horror|Mystery
# 6                     Memento (2000)Mystery|Thriller
# 7    Being John Malkovich (1999)Comedy|Drama|Fantasy
# 8  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 9                 American Beauty (1999)Comedy|Drama
#
#                                                   18  \
# 0              Grease 2 (1982)Comedy|Musical|Romance
# 1  Star Wars: Episode V - The Empire Strikes Back...
# 2          Blade Runner (1982)Action|Sci-Fi|Thriller
# 3                 Rear Window (1954)Mystery|Thriller
# 4  Speed 2: Cruise Control (1997)Action|Romance|T...
# 5  North by Northwest (1959)Action|Adventure|Myst...
# 6         Gone with the Wind (1939)Drama|Romance|War
# 7                   Godfather, The (1972)Crime|Drama
# 8                   Schindler's List (1993)Drama|War
# 9                     Casablanca (1942)Drama|Romance
#
#                                                   19
# 0      Slumdog Millionaire (2008)Crime|Drama|Romance
# 1           District 9 (2009)Mystery|Sci-Fi|Thriller
# 2  Sherlock Holmes (2009)Action|Crime|Mystery|Thr...
# 3          Avatar (2009)Action|Adventure|Sci-Fi|IMAX
# 4       Star Trek (2009)Action|Adventure|Sci-Fi|IMAX
# 5             Iron Man (2008)Action|Adventure|Sci-Fi
# 6  WALL·E (2008)Adventure|Animation|Children|Roma...
# 7        Up (2009)Adventure|Animation|Children|Drama
# 8     Dark Knight, The (2008)Action|Crime|Drama|IMAX
# 9  Inception (2010)Action|Crime|Drama|Mystery|Sci...

# %%
score = mean_absolute_error(y_true=dfs, y_pred=X)
score
# Out:
# 0.057216855495346206

# %% [markdown]
# # Our Very Own NMF Algorithm

# %%
def nmf(X,n_components,alpha,beta):
    """Calculates X = WH with a Hierarchical Alternating Least Squares (HALS) Method.
    X has a lot of missing values. For now, we use masks to only deal with the entries we have.
    This
    We could later implement Expectation Maximization (discussed here: https://archive.siam.org/meetings/sdm06/proceedings/059zhangs2.pdf)
    Parameters:
        X (m x n matrix) : Matrix to be factored
        n_components (int) : # of types to find (determines dimension of W and H)
        alpha (float) : regularization term
        maxiter (int) : Maximum # of iterations
    Returns:
        W : (m x n_components matrix)
        H : (n_components x n matrix)
        converged : whether or not it converged
        
        algorithm taken from : https://arxiv.org/pdf/1401.5226.pdf
    """
    eps = 1e-5 #threshold for zero
    
    #Initialize W,H     (use clustering or svd as initial matrices?)
    W0 = np.random.rand(X.shape[0],n_components)
    W0 = np.maximum(eps,W0)
    H0 = 
    
    #SPARSIFY THAT
    
    #update W and H with HALS
    converged = False
    for i in range(max_iter):
        for r in range(n_components):
        #first we do W
            lefthand = X@H0[r,:]
            righthand = np.sum([W0[:,k] * np.dot(H0[k,:],H0[r,:]) for k in range(n_components) if k != r], axis=0)
            bottom = la.norm(H0[r,:])
            W1[:,r] = np.maximum(eps,(lefthand - righthand) / bottom)
            
        for r in range(n_components):
        #then we do H
            lefthand = W1[:,r]@X
            righthand = np.sum([H0[r,:] * np.dot(W1[:,k],W1[:,r]) for k in range(n_components) if k != r], axis=0)
            bottom = la.norm(W1[:,r])
            H1[r,:] = np.maximum(eps,(lefthand - righthand) / bottom)
        
    return W,H,converged
